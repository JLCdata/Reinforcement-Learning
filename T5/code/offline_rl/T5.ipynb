# %% [markdown]
# # Evaluación del algoritmo

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **CartPole**

# %%
exp_11_1_CartPole=pd.read_csv("exp_11_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_11_2_CartPole=pd.read_csv("exp_11_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_11_3_CartPole=pd.read_csv("exp_11_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_21_1_CartPole=pd.read_csv("exp_21_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_21_2_CartPole=pd.read_csv("exp_21_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_21_3_CartPole=pd.read_csv("exp_21_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_31_1_CartPole=pd.read_csv("exp_31_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_31_2_CartPole=pd.read_csv("exp_31_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_31_3_CartPole=pd.read_csv("exp_31_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_12_1_CartPole=pd.read_csv("exp_12_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_12_2_CartPole=pd.read_csv("exp_12_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_12_3_CartPole=pd.read_csv("exp_12_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_22_1_CartPole=pd.read_csv("exp_22_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_22_2_CartPole=pd.read_csv("exp_22_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_22_3_CartPole=pd.read_csv("exp_22_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_32_1_CartPole=pd.read_csv("exp_32_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_32_2_CartPole=pd.read_csv("exp_32_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_32_3_CartPole=pd.read_csv("exp_32_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_13_1_CartPole=pd.read_csv("exp_13_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_13_2_CartPole=pd.read_csv("exp_13_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_13_3_CartPole=pd.read_csv("exp_13_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_23_1_CartPole=pd.read_csv("exp_23_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_23_2_CartPole=pd.read_csv("exp_23_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_23_3_CartPole=pd.read_csv("exp_23_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_33_1_CartPole=pd.read_csv("exp_33_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_33_2_CartPole=pd.read_csv("exp_33_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_33_3_CartPole=pd.read_csv("exp_33_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_14_1_CartPole=pd.read_csv("exp_14_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_14_2_CartPole=pd.read_csv("exp_14_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_14_3_CartPole=pd.read_csv("exp_14_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_24_1_CartPole=pd.read_csv("exp_24_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_24_2_CartPole=pd.read_csv("exp_24_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_24_3_CartPole=pd.read_csv("exp_24_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_34_1_CartPole=pd.read_csv("exp_34_1_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_34_2_CartPole=pd.read_csv("exp_34_2_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_34_3_CartPole=pd.read_csv("exp_34_3_CartPole.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})

# %% [markdown]
# # Exp 11

# %%
# join de experimentos
exp_11=exp_11_1_CartPole
for i in [exp_11_2_CartPole,exp_11_3_CartPole]:
    exp_11=exp_11.join(i)

# Promedio de experimentos
exp_11_mean=pd.DataFrame()
exp_11_mean["avg_reward"]=exp_11[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_11_mean["std_reward"]=exp_11[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_11_mean["success_rat"]=exp_11[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_11_mean.reset_index(inplace=True)
tr_steps_vec=exp_11_mean["steps"]
avg_reward_vec=exp_11_mean["avg_reward"]
std_reward_vec= exp_11_mean["std_reward"]
success_rate_vec=exp_11_mean["success_rat"]

# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_11")
plt.show()

# %% [markdown]
# # Exp 21

# %%
# join de experimentos
exp_21=exp_21_1_CartPole
for i in [exp_21_2_CartPole,exp_21_3_CartPole]:
    exp_21=exp_21.join(i)

# Promedio de experimentos
exp_21_mean=pd.DataFrame()
exp_21_mean["avg_reward"]=exp_21[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_21_mean["std_reward"]=exp_21[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_21_mean["success_rat"]=exp_21[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_21_mean.reset_index(inplace=True)
tr_steps_vec=exp_21_mean["steps"]
avg_reward_vec=exp_21_mean["avg_reward"]
std_reward_vec= exp_21_mean["std_reward"]
success_rate_vec=exp_21_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_21")
plt.show()

# %% [markdown]
# # Exp 31

# %%
# join de experimentos
exp_31=exp_31_1_CartPole
for i in [exp_31_2_CartPole,exp_31_3_CartPole]:
    exp_31=exp_31.join(i)

# Promedio de experimentos
exp_31_mean=pd.DataFrame()
exp_31_mean["avg_reward"]=exp_31[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_31_mean["std_reward"]=exp_31[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_31_mean["success_rat"]=exp_31[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_31_mean.reset_index(inplace=True)
tr_steps_vec=exp_31_mean["steps"]
avg_reward_vec=exp_31_mean["avg_reward"]
std_reward_vec= exp_31_mean["std_reward"]
success_rate_vec=exp_31_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_31")
plt.show()

# %% [markdown]
# # Exp 12

# %%
# join de experimentos
exp_12=exp_12_1_CartPole
for i in [exp_12_2_CartPole,exp_12_3_CartPole]:
    exp_12=exp_12.join(i)

# Promedio de experimentos
exp_12_mean=pd.DataFrame()
exp_12_mean["avg_reward"]=exp_12[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_12_mean["std_reward"]=exp_12[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_12_mean["success_rat"]=exp_12[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_12_mean.reset_index(inplace=True)
tr_steps_vec=exp_12_mean["steps"]
avg_reward_vec=exp_12_mean["avg_reward"]
std_reward_vec= exp_12_mean["std_reward"]
success_rate_vec=exp_12_mean["success_rat"]

# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_12")
plt.show()

# %% [markdown]
# # Exp 22

# %%
# join de experimentos
exp_22=exp_22_1_CartPole
for i in [exp_22_2_CartPole,exp_22_3_CartPole]:
    exp_22=exp_22.join(i)

# Promedio de experimentos
exp_22_mean=pd.DataFrame()
exp_22_mean["avg_reward"]=exp_22[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_22_mean["std_reward"]=exp_22[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_22_mean["success_rat"]=exp_22[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_22_mean.reset_index(inplace=True)
tr_steps_vec=exp_22_mean["steps"]
avg_reward_vec=exp_22_mean["avg_reward"]
std_reward_vec= exp_22_mean["std_reward"]
success_rate_vec=exp_22_mean["success_rat"]

# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_22")
plt.show()

# %% [markdown]
# # Exp 32

# %%
# join de experimentos
exp_32=exp_32_1_CartPole
for i in [exp_32_2_CartPole,exp_32_3_CartPole]:
    exp_32=exp_32.join(i)

# Promedio de experimentos
exp_32_mean=pd.DataFrame()
exp_32_mean["avg_reward"]=exp_32[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_32_mean["std_reward"]=exp_32[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_32_mean["success_rat"]=exp_32[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_32_mean.reset_index(inplace=True)
tr_steps_vec=exp_32_mean["steps"]
avg_reward_vec=exp_32_mean["avg_reward"]
std_reward_vec= exp_32_mean["std_reward"]
success_rate_vec=exp_32_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_32")
plt.show()

# %% [markdown]
# # Exp 13

# %%
# join de experimentos
exp_13=exp_13_1_CartPole
for i in [exp_13_2_CartPole,exp_13_3_CartPole]:
    exp_13=exp_13.join(i)

# Promedio de experimentos
exp_13_mean=pd.DataFrame()
exp_13_mean["avg_reward"]=exp_13[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_13_mean["std_reward"]=exp_13[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_13_mean["success_rat"]=exp_13[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_13_mean.reset_index(inplace=True)
tr_steps_vec=exp_13_mean["steps"]
avg_reward_vec=exp_13_mean["avg_reward"]
std_reward_vec= exp_13_mean["std_reward"]
success_rate_vec=exp_13_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_13")
plt.show()

# %% [markdown]
# # Exp 23

# %%
# join de experimentos
exp_23=exp_23_1_CartPole
for i in [exp_23_2_CartPole,exp_23_3_CartPole]:
    exp_23=exp_23.join(i)

# Promedio de experimentos
exp_23_mean=pd.DataFrame()
exp_23_mean["avg_reward"]=exp_23[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_23_mean["std_reward"]=exp_23[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_23_mean["success_rat"]=exp_23[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_23_mean.reset_index(inplace=True)
tr_steps_vec=exp_23_mean["steps"]
avg_reward_vec=exp_23_mean["avg_reward"]
std_reward_vec= exp_23_mean["std_reward"]
success_rate_vec=exp_23_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_23")
plt.show()

# %% [markdown]
# # Exp 33

# %%
# join de experimentos
exp_33=exp_33_1_CartPole
for i in [exp_33_2_CartPole,exp_33_3_CartPole]:
    exp_33=exp_33.join(i)

# Promedio de experimentos
exp_33_mean=pd.DataFrame()
exp_33_mean["avg_reward"]=exp_33[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_33_mean["std_reward"]=exp_33[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_33_mean["success_rat"]=exp_33[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_33_mean.reset_index(inplace=True)
tr_steps_vec=exp_33_mean["steps"]
avg_reward_vec=exp_33_mean["avg_reward"]
std_reward_vec= exp_33_mean["std_reward"]
success_rate_vec=exp_33_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_33")
plt.show()

# %% [markdown]
# # Exp 14

# %%
# join de experimentos
exp_14=exp_14_1_CartPole
for i in [exp_14_2_CartPole,exp_14_3_CartPole]:
    exp_14=exp_14.join(i)

# Promedio de experimentos
exp_14_mean=pd.DataFrame()
exp_14_mean["avg_reward"]=exp_14[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_14_mean["std_reward"]=exp_14[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_14_mean["success_rat"]=exp_14[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_14_mean.reset_index(inplace=True)
tr_steps_vec=exp_14_mean["steps"]
avg_reward_vec=exp_14_mean["avg_reward"]
std_reward_vec= exp_14_mean["std_reward"]
success_rate_vec=exp_14_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_14")
plt.show()

# %% [markdown]
# # Exp 24

# %%
# join de experimentos
exp_24=exp_24_1_CartPole
for i in [exp_24_2_CartPole,exp_24_3_CartPole]:
    exp_24=exp_24.join(i)

# Promedio de experimentos
exp_24_mean=pd.DataFrame()
exp_24_mean["avg_reward"]=exp_24[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_24_mean["std_reward"]=exp_24[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_24_mean["success_rat"]=exp_24[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_24_mean.reset_index(inplace=True)
tr_steps_vec=exp_24_mean["steps"]
avg_reward_vec=exp_24_mean["avg_reward"]
std_reward_vec= exp_24_mean["std_reward"]
success_rate_vec=exp_24_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_24")
plt.show()

# %% [markdown]
# # Exp 34

# %%
# join de experimentos
exp_34=exp_34_1_CartPole
for i in [exp_34_2_CartPole,exp_34_3_CartPole]:
    exp_34=exp_34.join(i)

# Promedio de experimentos
exp_34_mean=pd.DataFrame()
exp_34_mean["avg_reward"]=exp_34[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_34_mean["std_reward"]=exp_34[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_34_mean["success_rat"]=exp_34[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_34_mean.reset_index(inplace=True)
tr_steps_vec=exp_34_mean["steps"]
avg_reward_vec=exp_34_mean["avg_reward"]
std_reward_vec= exp_34_mean["std_reward"]
success_rate_vec=exp_34_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_34")
plt.show()

# %% [markdown]
# # MountainCar

# %%
exp_11_1_MountainCar=pd.read_csv("exp_11_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_11_2_MountainCar=pd.read_csv("exp_11_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_11_3_MountainCar=pd.read_csv("exp_11_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_21_1_MountainCar=pd.read_csv("exp_21_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_21_2_MountainCar=pd.read_csv("exp_21_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_21_3_MountainCar=pd.read_csv("exp_21_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_31_1_MountainCar=pd.read_csv("exp_31_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_31_2_MountainCar=pd.read_csv("exp_31_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_31_3_MountainCar=pd.read_csv("exp_31_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_12_1_MountainCar=pd.read_csv("exp_12_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_12_2_MountainCar=pd.read_csv("exp_12_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_12_3_MountainCar=pd.read_csv("exp_12_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_22_1_MountainCar=pd.read_csv("exp_22_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_22_2_MountainCar=pd.read_csv("exp_22_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_22_3_MountainCar=pd.read_csv("exp_22_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_32_1_MountainCar=pd.read_csv("exp_32_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_32_2_MountainCar=pd.read_csv("exp_32_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_32_3_MountainCar=pd.read_csv("exp_32_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_13_1_MountainCar=pd.read_csv("exp_13_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_13_2_MountainCar=pd.read_csv("exp_13_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_13_3_MountainCar=pd.read_csv("exp_13_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_23_1_MountainCar=pd.read_csv("exp_23_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_23_2_MountainCar=pd.read_csv("exp_23_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_23_3_MountainCar=pd.read_csv("exp_23_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_33_1_MountainCar=pd.read_csv("exp_33_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_33_2_MountainCar=pd.read_csv("exp_33_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_33_3_MountainCar=pd.read_csv("exp_33_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_14_1_MountainCar=pd.read_csv("exp_14_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_14_2_MountainCar=pd.read_csv("exp_14_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_14_3_MountainCar=pd.read_csv("exp_14_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_24_1_MountainCar=pd.read_csv("exp_24_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_24_2_MountainCar=pd.read_csv("exp_24_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_24_3_MountainCar=pd.read_csv("exp_24_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})
exp_34_1_MountainCar=pd.read_csv("exp_34_1_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward1","std_reward":"std_reward1","success_rate":"success_rat1"})
exp_34_2_MountainCar=pd.read_csv("exp_34_2_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward2","std_reward":"std_reward2","success_rate":"success_rat2"})
exp_34_3_MountainCar=pd.read_csv("exp_34_3_MountainCar.csv",names=['steps', 'avg_reward', 'std_reward',"success_rate"],header=1).set_index("steps").rename(columns={"avg_reward":"avg_reward3","std_reward":"std_reward3","success_rate":"success_rat3"})

# %% [markdown]
# # Exp 11

# %%
# join de experimentos
exp_11=exp_11_1_MountainCar
for i in [exp_11_2_MountainCar,exp_11_3_MountainCar]:
    exp_11=exp_11.join(i)

# Promedio de experimentos
exp_11_mean=pd.DataFrame()
exp_11_mean["avg_reward"]=exp_11[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_11_mean["std_reward"]=exp_11[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_11_mean["success_rat"]=exp_11[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_11_mean.reset_index(inplace=True)
tr_steps_vec=exp_11_mean["steps"]
avg_reward_vec=exp_11_mean["avg_reward"]
std_reward_vec= exp_11_mean["std_reward"]
success_rate_vec=exp_11_mean["success_rat"]

# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_11")
plt.show()

# %% [markdown]
# # Exp 21

# %%
# join de experimentos
exp_21=exp_21_1_MountainCar
for i in [exp_21_2_MountainCar,exp_21_3_MountainCar]:
    exp_21=exp_21.join(i)

# Promedio de experimentos
exp_21_mean=pd.DataFrame()
exp_21_mean["avg_reward"]=exp_21[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_21_mean["std_reward"]=exp_21[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_21_mean["success_rat"]=exp_21[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_21_mean.reset_index(inplace=True)
tr_steps_vec=exp_21_mean["steps"]
avg_reward_vec=exp_21_mean["avg_reward"]
std_reward_vec= exp_21_mean["std_reward"]
success_rate_vec=exp_21_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_21")
plt.show()

# %% [markdown]
# # Exp 31

# %%
# join de experimentos
exp_31=exp_31_1_MountainCar
for i in [exp_31_2_MountainCar,exp_31_3_MountainCar]:
    exp_31=exp_31.join(i)

# Promedio de experimentos
exp_31_mean=pd.DataFrame()
exp_31_mean["avg_reward"]=exp_31[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_31_mean["std_reward"]=exp_31[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_31_mean["success_rat"]=exp_31[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_31_mean.reset_index(inplace=True)
tr_steps_vec=exp_31_mean["steps"]
avg_reward_vec=exp_31_mean["avg_reward"]
std_reward_vec= exp_31_mean["std_reward"]
success_rate_vec=exp_31_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_31")
plt.show()

# %% [markdown]
# # Exp 12

# %%
# join de experimentos
exp_12=exp_12_1_MountainCar
for i in [exp_12_2_MountainCar,exp_12_3_MountainCar]:
    exp_12=exp_12.join(i)

# Promedio de experimentos
exp_12_mean=pd.DataFrame()
exp_12_mean["avg_reward"]=exp_12[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_12_mean["std_reward"]=exp_12[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_12_mean["success_rat"]=exp_12[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_12_mean.reset_index(inplace=True)
tr_steps_vec=exp_12_mean["steps"]
avg_reward_vec=exp_12_mean["avg_reward"]
std_reward_vec= exp_12_mean["std_reward"]
success_rate_vec=exp_12_mean["success_rat"]

# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_12")
plt.show()

# %% [markdown]
# # Exp 22

# %%
# join de experimentos
exp_22=exp_22_1_MountainCar
for i in [exp_22_2_MountainCar,exp_22_3_MountainCar]:
    exp_22=exp_22.join(i)

# Promedio de experimentos
exp_22_mean=pd.DataFrame()
exp_22_mean["avg_reward"]=exp_22[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_22_mean["std_reward"]=exp_22[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_22_mean["success_rat"]=exp_22[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_22_mean.reset_index(inplace=True)
tr_steps_vec=exp_22_mean["steps"]
avg_reward_vec=exp_22_mean["avg_reward"]
std_reward_vec= exp_22_mean["std_reward"]
success_rate_vec=exp_22_mean["success_rat"]

# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_22")
plt.show()

# %% [markdown]
# # Exp 32

# %%
# join de experimentos
exp_32=exp_32_1_MountainCar
for i in [exp_32_2_MountainCar,exp_32_3_MountainCar]:
    exp_32=exp_32.join(i)

# Promedio de experimentos
exp_32_mean=pd.DataFrame()
exp_32_mean["avg_reward"]=exp_32[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_32_mean["std_reward"]=exp_32[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_32_mean["success_rat"]=exp_32[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_32_mean.reset_index(inplace=True)
tr_steps_vec=exp_32_mean["steps"]
avg_reward_vec=exp_32_mean["avg_reward"]
std_reward_vec= exp_32_mean["std_reward"]
success_rate_vec=exp_32_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_32")
plt.show()

# %% [markdown]
# # Exp 13

# %%
# join de experimentos
exp_13=exp_13_1_MountainCar
for i in [exp_13_2_MountainCar,exp_13_3_MountainCar]:
    exp_13=exp_13.join(i)

# Promedio de experimentos
exp_13_mean=pd.DataFrame()
exp_13_mean["avg_reward"]=exp_13[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_13_mean["std_reward"]=exp_13[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_13_mean["success_rat"]=exp_13[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_13_mean.reset_index(inplace=True)
tr_steps_vec=exp_13_mean["steps"]
avg_reward_vec=exp_13_mean["avg_reward"]
std_reward_vec= exp_13_mean["std_reward"]
success_rate_vec=exp_13_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_13")
plt.show()

# %% [markdown]
# # Exp 23

# %%
# join de experimentos
exp_23=exp_23_1_MountainCar
for i in [exp_23_2_MountainCar,exp_23_3_MountainCar]:
    exp_23=exp_23.join(i)

# Promedio de experimentos
exp_23_mean=pd.DataFrame()
exp_23_mean["avg_reward"]=exp_23[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_23_mean["std_reward"]=exp_23[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_23_mean["success_rat"]=exp_23[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_23_mean.reset_index(inplace=True)
tr_steps_vec=exp_23_mean["steps"]
avg_reward_vec=exp_23_mean["avg_reward"]
std_reward_vec= exp_23_mean["std_reward"]
success_rate_vec=exp_23_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_23")
plt.show()

# %% [markdown]
# # Exp 33

# %%
# join de experimentos
exp_33=exp_33_1_MountainCar
for i in [exp_33_2_MountainCar,exp_33_3_MountainCar]:
    exp_33=exp_33.join(i)

# Promedio de experimentos
exp_33_mean=pd.DataFrame()
exp_33_mean["avg_reward"]=exp_33[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_33_mean["std_reward"]=exp_33[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_33_mean["success_rat"]=exp_33[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_33_mean.reset_index(inplace=True)
tr_steps_vec=exp_33_mean["steps"]
avg_reward_vec=exp_33_mean["avg_reward"]
std_reward_vec= exp_33_mean["std_reward"]
success_rate_vec=exp_33_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_33")
plt.show()

# %% [markdown]
# # Exp 14

# %%
# join de experimentos
exp_14=exp_14_1_MountainCar
for i in [exp_14_2_MountainCar,exp_14_3_MountainCar]:
    exp_14=exp_14.join(i)

# Promedio de experimentos
exp_14_mean=pd.DataFrame()
exp_14_mean["avg_reward"]=exp_14[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_14_mean["std_reward"]=exp_14[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_14_mean["success_rat"]=exp_14[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_14_mean.reset_index(inplace=True)
tr_steps_vec=exp_14_mean["steps"]
avg_reward_vec=exp_14_mean["avg_reward"]
std_reward_vec= exp_14_mean["std_reward"]
success_rate_vec=exp_14_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_14")
plt.show()

# %% [markdown]
# # Exp 24

# %%
# join de experimentos
exp_24=exp_24_1_MountainCar
for i in [exp_24_2_MountainCar,exp_24_3_MountainCar]:
    exp_24=exp_24.join(i)

# Promedio de experimentos
exp_24_mean=pd.DataFrame()
exp_24_mean["avg_reward"]=exp_24[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_24_mean["std_reward"]=exp_24[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_24_mean["success_rat"]=exp_24[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_24_mean.reset_index(inplace=True)
tr_steps_vec=exp_24_mean["steps"]
avg_reward_vec=exp_24_mean["avg_reward"]
std_reward_vec= exp_24_mean["std_reward"]
success_rate_vec=exp_24_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_24")
plt.show()

# %% [markdown]
# # Exp 34

# %%
# join de experimentos
exp_34=exp_34_1_MountainCar
for i in [exp_34_2_MountainCar,exp_34_3_MountainCar]:
    exp_34=exp_34.join(i)

# Promedio de experimentos
exp_34_mean=pd.DataFrame()
exp_34_mean["avg_reward"]=exp_34[["avg_reward1","avg_reward2","avg_reward3"]].mean(axis=1)
exp_34_mean["std_reward"]=exp_34[["std_reward1","std_reward2","std_reward3"]].mean(axis=1)
exp_34_mean["success_rat"]=exp_34[["success_rat1","success_rat2","success_rat3"]].mean(axis=1)
exp_34_mean.reset_index(inplace=True)
tr_steps_vec=exp_34_mean["steps"]
avg_reward_vec=exp_34_mean["avg_reward"]
std_reward_vec= exp_34_mean["std_reward"]
success_rate_vec=exp_34_mean["success_rat"]


# Plot
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

ax1.plot(tr_steps_vec, avg_reward_vec, color='C0')
ax1.fill_between(tr_steps_vec, avg_reward_vec-std_reward_vec, avg_reward_vec+std_reward_vec, color='C0', alpha=0.3)

ax1.set_ylabel('Avg Reward')
ax2.plot(tr_steps_vec, success_rate_vec, marker='.',color='C1')
ax2.set_ylabel('Success Rate')
ax1.set_xlabel('Steps')
ax2.set_xlabel('Steps')
plt.suptitle("exp_34")
plt.show()
